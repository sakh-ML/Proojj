# %%
#######https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction#######

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/ml-abu-saleh-ml/JUPYTER/DATASETS/heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df['ChestPainType'], _ = pd.factorize(df['ChestPainType'])
df['RestingECG'], _ = pd.factorize(df['RestingECG'])
df['ExerciseAngina'], _ = pd.factorize(df['ExerciseAngina'])
df['Sex'], _ = pd.factorize(df['Sex'])
df['ST_Slope'], _ = pd.factorize(df['ST_Slope'])
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.sample(10)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 1     49    1              1        160          180          0           0
# 55    51    1              0        160          194          0           0
# 7     54    0              0        110          208          0           0
# 892   39    1              1        138          220          0           0
# 654   48    0              2        122          222          0           2
# 261   54    1              0        120          221          0           0
# 461   63    0              2        136            0          0           0
# 121   52    1              1        125          272          0           0
# 793   67    0              2        125          254          1           0
# 240   55    0              0        145          326          0           0
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 1      156               0      1.0         1             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 86.2 KB

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
for label in df.columns[:-1]:
    plt.hist(df[df['HeartDisease'] == 1][label], color='red', label='Heart Disease', density=True,alpha=0.7)
    plt.hist(df[df['HeartDisease'] == 0][label], color='blue', label='No', density=True, alpha=0.7)
    plt.title(label)
    plt.ylabel('Probability')
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))  # Adjust figure size
sns.heatmap(
    df.corr(), 
    annot=True,         # Show correlation values
    fmt=".2f",          # Limit decimal places
    cmap="coolwarm",    # Choose a colormap
    linewidths=0.5,     # Add cell dividers
    square=True,        # Make cells square
    cbar_kws={"shrink": 0.8}  # Adjust colorbar size
)
plt.title("Correlation Heatmap", fontsize=14)  # Add a title
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x="ST_Slope", hue="HeartDisease", fill=True, common_norm=False, palette="coolwarm")
plt.title("ST_Slope vs Heart Disease Distribution")
plt.xlabel("ST_Slope")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x="ChestPainType", hue="HeartDisease", fill=True, common_norm=False, palette="coolwarm")
plt.title("ChestPainType vs Heart Disease Distribution")
plt.xlabel("ChestPainType")
plt.ylabel("Density")
plt.show()

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
df["HeartDisease"].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
value_distrubtion = df["HeartDisease"].value_counts()
plt.figure(figsize=(6,6))
sns.barplot(x = value_distrubtion.index, y = value_distrubtion.values)
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='HeartDisease')
y= df['HeartDisease']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state=106)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (734, 11)
# (184, 11)
# (734,)
# (184,)

# %%
#Logistic Regression !!!
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.875

# %%
#Random Forest CLassifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=250)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=250)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.875

# %%
#Support vector maschine 
from sklearn.svm import SVC

model = SVC(kernel="rbf")
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.7228260869565217
